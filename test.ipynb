# %%
class Student:
    def __init__(self, name, age, gender, roll_num):
        self.name = name
        self.age = age
        self.gender = gender
        self.roll_num = roll_num

    def introduce_self(self):
        print(f"Hello, my name is {self.name}. I am {self.age} years old.")
        print(type(self.name))

# Example usage
student1 = Student("John Doe", 18, "Male", 1234)
student1.introduce_self()
# Out:
# Hello, my name is John Doe. I am 18 years old.
# <class 'str'>

# %%
hello = 4

# %%
print(hello)
# Out:
# 4
